# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import urllib
import requests
import re

# %% [markdown]
# # Ongoing problems:
# when I start trying to query sparql for a bunch of articles that contain 'open science' in the abstract, I keep getting this 502 proxy error. At the moment, my best guess is that this is some kind of timeout. When I go to the ma-graph endpoint and paste in the same text, but specify the timeout thing to be long, I get data back (though perhaps not everything I should). My next stage is, I think, to start looking into timeouts.
#
# If that fails, I can download the dumps. I presently have 1tb of storage on this machine. prom has about 2.5tb and could maybe get more on prom.
#
# # Data description
# Here, I'm pulling data out of a sparql database that includes information from microsoft academic knowledge graph. The website for this data is here: http://ma-graph.org/

# %%
sparql = SPARQLWrapper('http://ma-graph.org/sparql')

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX magp: <http://ma-graph.org/property/>
PREFIX mag: <http://ma-graph.org/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cito: <http://purl.org/spar/cito/>
PREFIX c4o: <http://purl.org/spar/c4o/>
PREFIX prism: <http://prismstandard.org/namespaces/1.2/basic/>
PREFIX datacite: <http://purl.org/spar/datacite/>

SELECT ?nihauthname ?otherauths ?papertitle ?discname ?dt ?doi ?abst
WHERE {
# ?inst rdf:type <http://ma-graph.org/class/Affiliation> .
# ?inst foaf:name "National Institutes of Health"^^xsd:string .
# ?auth org:memberOf ?inst .
# ?paper dcterms:creator ?auth .
# ?auth foaf:name ?nihauthname .
# ?paper dcterms:creator ?allauths .
# ?allauths foaf:name ?otherauths .
# ?paper dcterms:title ?papertitle .
# ?paper prism:publicationDate ?dt .
# ?paper fabio:hasDiscipline ?disc .
# ?paper datacite:doi ?doi .
# ?paper dcterms:abstract ?abst .
# ?disc foaf:name ?discname .
}
""")

# %%
#?paper cito:hasCitedEntity ?cit .
#?cit c4o:hasContext ?citcont .

# %%
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
len(results['results']['bindings'])
# Out:
# 1048576

# %%
results['results']['bindings'][10000]
# Out:
# {'nihauthname': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': 'Scott R. Budihas'},
#  'otherauths': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': 'Michael A. Parniak'},
#  'papertitle': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': 'A capillary electrophoretic assay for ribonuclease H activity.'},
#  'discname': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': 'Biochemistry'},
#  'dt': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#   'value': '2004-08-01'},
#  'doi': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': '10.1016/j.ab.2004.05.017'},
#  'abst': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': 'Abstract A capillary electrophoretic assay was developed to measure the ribonuclease (RNase) H activity of human immunodeficiency virus (HIV) type 1 reverse transcriptase. Cleavage of a fluorescein-labeled RNA\x13DNA heteroduplex was monitored by capillary electrophoresis. This new assay was used as a secondary assay to confirm hits from a high-throughput screening program. Since autofluorescent compounds in samples migrated differently from both substrate and product in most cases, the assay was extremely robust for assaying enzymatic inhibition of such samples, in contrast to a simple well-based approach. The assay was broadly applicable to other RNases H, specifically those from human, Escherichia coli , and HIV-2, although product profiles varied for each enzyme.'}}

# %%
outdat = []
for i in results['results']['bindings']:
    outdat.append([i['papertitle']['value'], i['authname']['value'], 
                   i['discname']['value'], i['dt']['value'], i['doi']['value']])

# %%
dat = pd.DataFrame(outdat, columns = ['title', 'author', 'field', 'date', 'doi'])

# %%
dat[dat.doi=='10.1128/genomeA.01093-15']
# Out:
#                                                     title  \
# 0       Molecular Signature of the Ebola Virus Associa...
# 1       Molecular Signature of the Ebola Virus Associa...
# 2       Molecular Signature of the Ebola Virus Associa...
# 3       Molecular Signature of the Ebola Virus Associa...
# 4       Molecular Signature of the Ebola Virus Associa...
# 5       Molecular Signature of the Ebola Virus Associa...
# 160224  Molecular Signature of the Ebola Virus Associa...
# 160225  Molecular Signature of the Ebola Virus Associa...
# 160226  Molecular Signature of the Ebola Virus Associa...
# 160227  Molecular Signature of the Ebola Virus Associa...
# 160228  Molecular Signature of the Ebola Virus Associa...
# 160229  Molecular Signature of the Ebola Virus Associa...
# 391311  Molecular Signature of the Ebola Virus Associa...
# 391312  Molecular Signature of the Ebola Virus Associa...
# 391313  Molecular Signature of the Ebola Virus Associa...
# 391314  Molecular Signature of the Ebola Virus Associa...
# 391315  Molecular Signature of the Ebola Virus Associa...
# 391316  Molecular Signature of the Ebola Virus Associa...
#
#                       author           field        date  \
# 0       Concetta Castilletti     Ebola virus  2015-10-29
# 1       Concetta Castilletti        Virology  2015-10-29
# 2       Concetta Castilletti        Subclade  2015-10-29
# 3       Concetta Castilletti        Outbreak  2015-10-29
# 4       Concetta Castilletti  Bioinformatics  2015-10-29
# 5       Concetta Castilletti         Biology  2015-10-29
# 160224         Silvia Meschi     Ebola virus  2015-10-29
# 160225         Silvia Meschi        Virology  2015-10-29
# 160226         Silvia Meschi        Subclade  2015-10-29
# 160227         Silvia Meschi        Outbreak  2015-10-29
# 160228         Silvia Meschi  Bioinformatics  2015-10-29
# 160229         Silvia Meschi         Biology  2015-10-29
# 391311      Antonino Di Caro     Ebola virus  2015-10-29
# 391312      Antonino Di Caro        Virology  2015-10-29
# 391313      Antonino Di Caro        Subclade  2015-10-29
# 391314      Antonino Di Caro        Outbreak  2015-10-29
# 391315      Antonino Di Caro  Bioinformatics  2015-10-29
# 391316      Antonino Di Caro         Biology  2015-10-29
#
#                              doi
# 0       10.1128/genomeA.01093-15
# 1       10.1128/genomeA.01093-15
# 2       10.1128/genomeA.01093-15
# 3       10.1128/genomeA.01093-15
# 4       10.1128/genomeA.01093-15
# 5       10.1128/genomeA.01093-15
# 160224  10.1128/genomeA.01093-15
# 160225  10.1128/genomeA.01093-15
# 160226  10.1128/genomeA.01093-15
# 160227  10.1128/genomeA.01093-15
# 160228  10.1128/genomeA.01093-15
# 160229  10.1128/genomeA.01093-15
# 391311  10.1128/genomeA.01093-15
# 391312  10.1128/genomeA.01093-15
# 391313  10.1128/genomeA.01093-15
# 391314  10.1128/genomeA.01093-15
# 391315  10.1128/genomeA.01093-15
# 391316  10.1128/genomeA.01093-15

# %%
dat.groupby('field').count()[['title']].sort_values('title', ascending=False)
# Out:
#                                 title
# field
# Biology                         56725
# Medicine                        41832
# Molecular biology               23265
# Immunology                      22135
# Internal medicine               19022
# Virology                        15039
# Biochemistry                    14901
# Endocrinology                   13882
# Genetics                        13696
# Cancer                           9490
# Chemistry                        8870
# Pathology                        8655
# Cancer research                  7490
# Diabetes mellitus                6095
# Gene                             5912
# Psychology                       5773
# Virus                            5252
# Physical therapy                 4983
# Immune system                    4951
# Antibody                         4856
# Disease                          4786
# Cardiology                       4611
# Cell biology                     4440
# Antigen                          4089
# Surgery                          4022
# Receptor                         3610
# Anatomy                          3413
# Anesthesia                       2886
# T cell                           2751
# Mutation                         2588
# ...                               ...
# Linear molecular geometry           1
# Linear no-threshold model           1
# Linear phase                        1
# Linear predictor function           1
# Ligneous conjunctivitis             1
# Lightness                           1
# Light-harvesting complex            1
# Light-emitting diode                1
# Levinthal&#039;s paradox            1
# Levoamphetamine                     1
# Levodopa-induced dyskinesia         1
# Levorphanol                         1
# Lewis acid catalysis                1
# Leydig cell hypoplasia              1
# Liberalism                          1
# LibmanSacks endocarditis           1
# Library management                  1
# Lichtheimia corymbifera             1
# Lidoflazine                         1
# Lien                                1
# Life skills                         1
# Life support                        1
# Lifestyle management                1
# Lift (force)                        1
# Ligature                            1
# Light beam                          1
# Light chain deposition disease      1
# Light field                         1
# Light scattering by particles       1
# xDNA                                1
#
# [29873 rows x 1 columns]

# %% [markdown]
# # URL presence
#
# To what extent have open-data repositories been adopted? Have some repositories been adopted more quickly than others? Does this vary by field?
#
# These questions have bearing on our understanding of the effects of open-data, and open science more generally. In principle, open science is designed to facilitate the participation of a wide range of people in the scientific community. If groups that have a disproportionate share of resources consistently publish their likely resource-intensive datasets, then these valuable datasets can be mined by a wider range of individuals for scientific insights.
#
# To this end, I will examine how frequently URL's to some prominent open science repositories are present in papers as urls

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX magp: <http://ma-graph.org/property/>
PREFIX mag: <http://ma-graph.org/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cito: <http://purl.org/spar/cito/>
PREFIX datacite: <http://purl.org/spar/datacite/>
PREFIX prism: <http://prismstandard.org/namespaces/1.2/basic/>
PREFIX c4o: <http://purl.org/spar/c4o/>

SELECT ?paper ?paptitle ?abst ?dt ?ln ?auth ?doi ?estCites
WHERE {
# ?paper rdf:type <http://ma-graph.org/class/Paper> .
# ?paper dcterms:title ?paptitle .
# ?paper dcterms:abstract ?abst .
# ?paper prism:publicationDate ?dt .
# ?paper dcterms:creator ?auth .
# ?paper datacite:doi ?doi .
# ?paper dcterms:language ?ln .
# ?paper dcterms:creator ?auth .
}
""")

# %%
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
len(results['results']['bindings'])
# Out:
# 1048576

# %%
results['results']['bindings'][2]
# Out:
# {'paper': {'type': 'uri', 'value': 'http://ma-graph.org/entity/4524729'},
#  'paptitle': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': 'Fiber Optics Sensors'},
#  'abst': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': 'Fiber optic technology started in 1970\x19s, for long distance telecommunications, and it has experienced an exponential growth during the last four decades. Sensing applications are a small spin-off from this technology, taking profit of developments done for optoelectronic components and concepts. Optical fibers are cylindrical dielectric waveguides for the propagation of the light, made out from high purity, low loss optical materials, usually silica (Optical fibers made from polymers and other transparent materials are also commercially available). The refractive index of the core (about 1.46 for silica) is slightly higher than surrounding material or cladding, due to the presence of dopants. Light is confined at the core, because optical rays arriving to the interface core/cladding with an angle higher than the total reflectance angle, as defined by the Snell law, will follow total reflections and will remain confined at the core. Only when the fiber is locally bent with a sharp radius, the light may escape.'},
#  'dt': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#   'value': '2013-01-01'},
#  'ln': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#language',
#   'value': 'en'},
#  'doi': {'type': 'typed-literal',
#   'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#   'value': '10.1007/978-3-7091-1390-5_5'}}

# %%
outdat = []
for i in results['results']['bindings']:
    outdat.append([i['paper']['value'], i['paptitle']['value'], 
                   i['abst']['value'], i['dt']['value'], i['ln']['value'],
                   i['doi']['value']])

# %%
dat = pd.DataFrame(outdat, columns = ['paper', 'title', 'abstract', 'date',
                                      'language', 'doi'])
dat = dat[dat.lang=='en']
dat['open_science'] = dat.abstract.str.contains('open science', case=False)

# %%
dat.to_pickle('/home/riddleta/ac_knowl/output/testdat.pkl')

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX magp: <http://ma-graph.org/property/>
PREFIX mag: <http://ma-graph.org/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cito: <http://purl.org/spar/cito/>
PREFIX datacite: <http://purl.org/spar/datacite/>
PREFIX prism: <http://prismstandard.org/namespaces/1.2/basic/>
PREFIX c4o: <http://purl.org/spar/c4o/>

SELECT ?author ?dt ?cites ?papes ?authname ?rnk ?inst
WHERE {
# ?author rdf:type <http://ma-graph.org/class/Author> .
}
""")

# %%
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
len(results['results']['bindings'])
# Out:
# 1048576

# %% [markdown]
# imagine a matrix of field x institution/author, with the cells of the matrix representing either counts of papers, or binary occurrences. What fields have a diversity of authors/institutions? what are more monopolistics? what are the consequences of the differences between these especially over time?
#
# is there an association between data sharing and market concentration (e.g. hh index)?
#
# also, look at what aaron clausett has been working on
#
# http://www.semantic-web-journal.net/system/files/swj1495.pdf
#
# group differences in "tenure rates, competency evaluations, remuneration, allocation of research facilities, and
# grant competitions" (way, larremore & clauset, 2016)
#
#
# plots to make:
#
# prevalency of links to various data-sharing platforms over time (see the [google spreadsheet](https://docs.google.com/spreadsheets/d/14GSgOppnvjS-pxGz1__fEBuj3KUNgKB7ni5nukHT8Ps/edit#gid=2016420688) for links)
#
# market concentration by...author? institution?

# %% [markdown]
# # Aaron Clauset:
# https://arxiv.org/abs/1612.08228
#
# https://arxiv.org/abs/1804.02760
#
# https://arxiv.org/abs/1805.09966

# %% [markdown]
# # Dani Bassett:
# https://arxiv.org/abs/1810.10534
#
# https://arxiv.org/abs/1804.06434
#
# https://www.sciencedirect.com/science/article/pii/S105381191830778X?via%3Dihub

# %% [markdown]
# # Jevin West:
# https://jevinwest.org/papers/West2013PLoSOne.pdf
#
# https://jevinwest.org/papers/West2014EconInquiry.pdf
#
# https://jevinwest.org/papers/Vilhena2014SocScience.pdf
#
# https://jevinwest.org/papers/Larsen2014HICSS.pdf
#
# https://jevinwest.org/papers/Portenoy2016WWW.pdf
#
# https://jevinwest.org/papers/Kim2017asa.pdf
#
# https://jevinwest.org/papers/Chow2017fisheries.pdf
#
# https://jevinwest.org/papers/King2017socius.pdf
#
# https://jevinwest.org/papers/Piwowar2018peerj.pdf
#
#
# # Michael Farber
# http://dbis.informatik.uni-freiburg.de/content/team/faerber/papers/arXiv_Dataset_BIR2019.pdf
#
#
#
# # Other:
# https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1005962
#
# https://cdn.elifesciences.org/articles/32822/elife-32822-v2.pdf
#
# https://academic.oup.com/bioinformatics/advance-article/doi/10.1093/bioinformatics/btz070/5305021
#
# https://link.springer.com/article/10.1007/s11192-012-0900-9
#
# https://link.springer.com/chapter/10.1007/978-3-319-67056-0_18
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5761855/
#
# https://onlinelibrary.wiley.com/doi/full/10.1002/asi.23266

# %%
# datasets
# arxiv (downloaded)
# https://www.ncbi.nlm.nih.gov/research/bionlp/APIs/BioC-PMC/

# %% [markdown]
# # Pulling arxiv papers

# %%
f = open('/Downloads/arxiv_v2.1/0704.0001.txt','w') 
print(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-78fa68d43234> in <module>
# ----> 1 f = open('/Downloads/arxiv_v2.1/0704.0001.txt','w')
#       2 print(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Downloads/arxiv_v2.1/0704.0001.txt'

# %% [markdown]
# # Get the pubmed papers

# %%
#bioc-pmc files
files_to_get = pd.read_table('/home/riddleta/ac_knowl/data/filelist.txt', sep='\s+')
files_to_get.shape
# Out:
# /home/riddleta/ac_knowl/ac_knowl/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
# (598386, 4)

# %%
oa_comm_use_files = pd.read_csv('/home/riddleta/ac_knowl/data/oa_comm_use_file_list.txt', 
                                sep='\\t', engine='python', header=None, skiprows=1)
oa_comm_use_files.columns = ['File', 'ref', 'PMCID', 'PMID', 'license']
oa_comm_use_files.shape
# Out:
# (1479862, 5)

# %%
oa_files = pd.read_table('/home/riddleta/ac_knowl/data/oa_file_list.txt', 
                         sep='\\t', engine='python', header=None, skiprows=1)
oa_files.columns = ['File', 'ref', 'PMCID', 'PMID', 'license']
oa_files.shape
# Out:
# /home/riddleta/ac_knowl/ac_knowl/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
# (2408932, 5)

# %%
unique_ids = pd.concat([oa_files['PMCID'], oa_comm_use_files['PMCID'], files_to_get['PMCID']]).unique()

# %%
def return_useful_data(r):
    git_hits = 0
    osf_hits = 0
    nda_hits = 0
    open_neuro = 0
    fmri = 0
    res = 0
    r_out = r.json()
    date = r_out['date']
    src = r_out['source']
    try:
        doi = r_out['documents'][0]['passages'][0]['infons']['article-id_doi']
    except:
        doi = None
    try:
        yr = r_out['documents'][0]['passages'][0]['infons']['year']
    except:
        yr = None
    if yr not in ['2008', '2009', '2010', '2011', '2012', '2013', 
                  '2014', '2015', '2016', '2017', '2018', '2019']:
        return(date, src, doi, git_hits, osf_hits, nda_hits, open_neuro, fmri, res, yr)
    else:
        for passage in r_out['documents'][0]['passages']:
            if re.search(re.compile('github'), passage['text'].lower()):
                git_hits = git_hits + 1
            if re.search(re.compile('osf\.io'), passage['text'].lower()):
                osf_hits = osf_hits + 1
            if re.search(re.compile('nda\.nih\.gov'), passage['text'].lower()):
                nda_hits = nda_hits + 1
            if re.search(re.compile('openneuro'), passage['text'].lower()):
                open_neuro = open_neuro + 1
            if re.search(re.compile('fmri'), passage['text'].lower()):
                fmri = fmri + 1
            if re.search(re.compile('results'), passage['text'].lower()):
                res = res + 1
        
        return(date, src, doi, git_hits, osf_hits, nda_hits, open_neuro, fmri, res, yr)

# %%
git_links = []
for i, j in enumerate(unique_ids):
    pth = 'https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_json/' + j + '/unicode'
    r = requests.get(pth)
    git_links.append(return_useful_data(r) + (j, i))
    if i==10000:
        break

# %%
df = pd.DataFrame(git_links, columns=['date', 'src', 'doi', 'git_hits', 
                                      'osf_hits', 'nda_hits', 'open_neuro', 
                                      'fmri', 'res', 'yr', 'pmcid', 'idx'])
df.to_csv('/home/riddleta/ac_knowl/output/bionlp_10k.csv')

# %%
git_links = []
for i, j in enumerate(unique_ids[10000:]):
    pth = 'https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_json/' + j + '/unicode'
    r = requests.get(pth)
    git_links.append(return_useful_data(r) + (j, i))
    if i==15000:
        break

# %%
df = pd.DataFrame(git_links, columns=['date', 'src', 'doi', 'git_hits', 
                                      'osf_hits', 'nda_hits', 'open_neuro', 
                                      'fmri', 'res', 'yr', 'pmcid', 'idx'])
df.to_csv('/home/riddleta/ac_knowl/output/bionlp_02.csv')

# %%
git_links = []
missed = []

for i, j in enumerate(unique_ids[25000:]):
    pth = 'https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_json/' + j + '/unicode'
    try:
        r = requests.get(pth)
        git_links.append(return_useful_data(r) + (j, i))
    except:
        missed.append([i,j])
    if i==20000:
        break
df = pd.DataFrame(git_links, columns=['date', 'src', 'doi', 'git_hits', 
                                      'osf_hits', 'nda_hits', 'open_neuro', 
                                      'fmri', 'res', 'yr', 'pmcid', 'idx'])
df.to_csv('/home/riddleta/ac_knowl/output/bionlp_03.csv')

# %%
git_links = []
missed = []

for i, j in enumerate(unique_ids[45000:]):
    pth = 'https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_json/' + j + '/unicode'
    try:
        r = requests.get(pth)
        git_links.append(return_useful_data(r) + (j, i))
    except:
        missed.append([i,j])
    if i==25000:
        break

# %%
i

# %%
df = pd.DataFrame(git_links, columns=['date', 'src', 'doi', 'git_hits', 
                                      'osf_hits', 'nda_hits', 'open_neuro', 
                                      'fmri', 'res', 'yr', 'pmcid', 'idx'])
df.to_csv('/home/riddleta/ac_knowl/output/bionlp_03.csv')
# Out:
#         date  src                      doi  git_hits  osf_hits  nda_hits  \
# 0   20181121  PMC   10.1186/1743-8462-2-29         0         0         0
# 1   20181121  PMC  10.1186/1471-2334-5-116         0         0         0
# 2   20181121  PMC  10.1186/1471-2105-6-282         0         0         0
# 3   20181121  PMC       10.1093/nar/gkj431         0         0         0
# 4   20181121  PMC       10.1093/nar/gkj441         0         0         0
# 5   20181121  PMC       10.1093/nar/gkj453         0         0         0
# 6   20181121  PMC       10.1093/nar/gkj461         0         0         0
# 7   20181124  PMC       10.1093/nar/gkj463         0         0         0
# 8   20181121  PMC       10.1093/nar/gkj468         0         0         0
# 9   20181121  PMC       10.1093/nar/gnj008         0         0         0
# 10  20181112  PMC       10.1093/nar/gnj010         0         0         0
# 11  20181112  PMC       10.1093/nar/gnj012         0         0         0
# 12  20181112  PMC       10.1093/nar/gnj015         0         0         0
# 13  20181202  PMC       10.1093/nar/gkj002         0         0         0
# 14  20190104  PMC       10.1093/nar/gkj003         0         0         0
# 15  20181130  PMC       10.1093/nar/gkj004         0         0         0
# 16  20181123  PMC       10.1093/nar/gkj005         0         0         0
# 17  20181123  PMC       10.1093/nar/gkj006         0         0         0
# 18  20181207  PMC       10.1093/nar/gkj007         0         0         0
# 19  20181207  PMC       10.1093/nar/gkj008         0         0         0
# 20  20181207  PMC       10.1093/nar/gkj009         0         0         0
#
#     open_neuro  fmri  res    yr       pmcid  idx
# 0            0     0    0  2005  PMC1345690    0
# 1            0     0    0  2005  PMC1345691    1
# 2            0     0    0  2005  PMC1345692    2
# 3            0     0    0  2006  PMC1345693    3
# 4            0     0    0  2006  PMC1345694    4
# 5            0     0    0  2006  PMC1345695    5
# 6            0     0    0  2006  PMC1345696    6
# 7            0     0    0  2006  PMC1345697    7
# 8            0     0    0  2006  PMC1345698    8
# 9            0     0    0  2006  PMC1345699    9
# 10           0     0    0  2006  PMC1345700   10
# 11           0     0    0  2006  PMC1345701   11
# 12           0     0    0  2006  PMC1345702   12
# 13           0     0    0  2005  PMC1347365   13
# 14           0     0    0  2005  PMC1347366   14
# 15           0     0    0  2005  PMC1347367   15
# 16           0     0    0  2005  PMC1347368   16
# 17           0     0    0  2005  PMC1347369   17
# 18           0     0    0  2005  PMC1347370   18
# 19           0     0    0  2005  PMC1347371   19
# 20           0     0    0  2005  PMC1347372   20

# %%
len(unique_ids)
# Out:
# 2975022

# %%
tmpyr = '2011'
int(tmpyr)
# Out:
# 2011

# %%
github_ex = re.compile('github')
re.search(github_ex, r_out['documents'][0]['passages'][0]['text'])

# %%
return_useful_data(r) + (j, i)
# Out:
# ('20181121', 'PMC', 0, 0, 0, 0, 0, 'PMC126257', 350)

# %%
r_out['date']
# Out:
# '20181121'

# %%
r_out['documents'][0]['passages'][0]['text'].lower()
# Out:
# 'resolution of airway inflammation and hyperreactivity after in vivo transfer of cd4+cd25+ regulatory t cells is interleukin 10 dependent'

# %%
temp_txt = 'resolution of airway inflammation and hyperreactivity after in vivo transfer of cd4+cd25+ regulatory t cells is interleukin 10 dependent. we also posted our data on github.com'

# %%
re.search(re.compile('github'), temp_txt.lower())
# Out:
# <re.Match object; span=(165, 171), match='github'>

# %%
r = requests.get('https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_json/PMC1350743/unicode')

# %%
r_out = r.json()

# %%
r_out['documents'][0]['passages'][0]['infons']['year']
# Out:
# '2005'

# %%
re.findall(github_ex, passage['text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cfd888f400ac> in <module>
# ----> 1 re.findall(github_ex, passage['text'])
#
# NameError: name 'github_ex' is not defined

# %%
for passage in r_out['documents'][0]['passages']:
    print(passage['infons']['section_type'])
# Out:
# TITLE
# ABSTRACT
# INTRO
# INTRO
# INTRO
# RESULTS
# RESULTS
# RESULTS
# RESULTS
# RESULTS
# RESULTS
# FIG
# RESULTS
# RESULTS
# RESULTS
# FIG
# RESULTS
# RESULTS
# RESULTS
# RESULTS
# RESULTS
# RESULTS
# FIG
# RESULTS
# RESULTS
# FIG
# RESULTS
# RESULTS
# FIG
# DISCUSS
# DISCUSS
# DISCUSS
# DISCUSS
# DISCUSS
# DISCUSS
# DISCUSS
# DISCUSS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# METHODS
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF
# REF

# %%
r_out['documents'][0]['passages'][0]
# Out:
# {'text': 'Resolution of airway inflammation and hyperreactivity after in vivo transfer of CD4+CD25+ regulatory T cells is interleukin 10 dependent',
#  'offset': 0,
#  'relations': [],
#  'infons': {'name_2': 'surname:Robinson;given-names:Douglas S.',
#   'name_3': 'surname:Lloyd;given-names:Clare M.',
#   'name_0': 'surname:Kearley;given-names:Jennifer',
#   'name_1': 'surname:Barker;given-names:Jane E.',
#   'license': 'This article is distributed under the terms of an Attribution–Noncommercial–Share Alike–No Mirror Sites license for the first six months after the publication date (see http://www.rupress.org/terms). After six months it is available under a Creative Commons License (Attribution–Noncommercial–Share Alike 4.0 Unported license, as described at http://creativecommons.org/licenses/by-nc-sa/4.0/).',
#   'article-id_publisher-id': '20051166',
#   'issue': '11',
#   'article-id_doi': '10.1084/jem.20051166',
#   'section_type': 'TITLE',
#   'article-id_pmid': '16314435',
#   'lpage': '1547',
#   'article-id_pmc': '1350743',
#   'fpage': '1539',
#   'year': '2005',
#   'type': 'front',
#   'fn': 'Abbreviations used: AHR, airway hyperreactivity; BAL, bronchoalveolar lavage; Cdyn, dynamic compliance; RL, lung resistance.',
#   'volume': '202'},
#  'sentences': [],
#  'annotations': []}
